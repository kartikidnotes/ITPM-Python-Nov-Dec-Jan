# %%
# Check balance 

def check_balance(amount):
    print("Your Current Balance is :: ",amount)


check_balance(50000)
# Out:
# Your Current Balance is ::  50000

# %%
# have a discount 

def applydiscount(bill):
    discount=bill*0.35
    final_bill=bill-discount
    print("Discount is :: ",discount)
    print("Final BIll After Discount is :: ",final_bill)

applydiscount(20000)
# Out:
# Discount is ::  7000.0
# Final BIll After Discount is ::  13000.0

# %%
# area of circle

def area():
    radius=float(input("Enter radius ::: "))
    area=3.14*radius*radius
    print("area of circle is :: ",area)


area()
area()
area()
# Out:
# area of circle is ::  109.30340000000002
# area of circle is ::  307.75140000000005
# area of circle is ::  1218.6026

# %%
# factorial

def factorial():
    num=int(input("Enter number :: "))
    fact=1
    for i in range(1,num+1):
        fact=fact*i
        i=i+1

    print("Factorial is :: ",fact)

factorial()
factorial()
# Out:
# Factorial is ::  120
# Factorial is ::  24
